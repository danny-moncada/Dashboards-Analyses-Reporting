# %%
[cloudera@quickstart data_ingest]$ hadoop fs -ls -h
Found 9 items
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_18
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_19
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_20
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_21
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 23:58 count2
drwxr-xr-x   - cloudera cloudera          0 2017-08-01 03:57 empcounts
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:45 shakespeare
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:43 testlog
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:41 weblog
[cloudera@quickstart data_ingest]$ hadoop fs -put $ADIR/data/access.log /dualcore
[cloudera@quickstart data_ingest]$ hadoop fs -ls /dualcore
Found 1 items
-rw-r--r--   1 cloudera supergroup  106339468 2019-06-14 14:54 /dualcore/access.log
[cloudera@quickstart data_ingest]$ hadoop fs -rm -r /dualcore/access.log
Deleted /dualcore/access.log
[cloudera@quickstart data_ingest]$ hadoop fs -mkdir /weblog
[cloudera@quickstart data_ingest]$ gunzip -c ~/training_materials/developer/data/access_log.gz \ | hadoop fs -put - weblog/access_log
put: `weblog/access_log': File exists
[cloudera@quickstart data_ingest]$ hadoop fs -ls
Found 9 items
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_18
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_19
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_20
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_21
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 23:58 count2
drwxr-xr-x   - cloudera cloudera          0 2017-08-01 03:57 empcounts
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:45 shakespeare
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:43 testlog
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:41 weblog
[cloudera@quickstart data_ingest]$ hadoop fs -ls /weblog
[cloudera@quickstart data_ingest]$ hadoop fs -rm -r weblog
Deleted weblog
[cloudera@quickstart data_ingest]$ hadoop fs -ls
Found 8 items
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_18
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_19
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_20
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_21
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 23:58 count2
drwxr-xr-x   - cloudera cloudera          0 2017-08-01 03:57 empcounts
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:45 shakespeare
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:43 testlog
[cloudera@quickstart data_ingest]$ hadoop fs -mkdir /weblog
mkdir: `/weblog': File exists
[cloudera@quickstart data_ingest]$ hadoop fs -mkdir weblog
[cloudera@quickstart data_ingest]$ hadoop fs -ls
Found 9 items
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_18
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_19
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_20
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_21
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 23:58 count2
drwxr-xr-x   - cloudera cloudera          0 2017-08-01 03:57 empcounts
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:45 shakespeare
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:43 testlog
drwxr-xr-x   - cloudera cloudera          0 2019-06-14 15:07 weblog
[cloudera@quickstart data_ingest]$ gunzip -c ~/training_materials/developer/data/access_log.gz \ | hadoop fs -put - weblog/access_log
gzip:  .gz: No such file or directory
[cloudera@quickstart data_ingest]$ gunzip -c ~/training_materials/developer/data/access_log.gz | hadoop fs -put - weblog/access_log
put: `weblog/access_log': File exists
[cloudera@quickstart data_ingest]$ hadoop fs -ls weblog
Found 1 items
-rw-r--r--   1 cloudera cloudera  504941532 2019-06-14 15:08 weblog/access_log
[cloudera@quickstart data_ingest]$ hadoop fs -mkdir testlog
mkdir: `testlog': File exists
[cloudera@quickstart data_ingest]$ hadoop fs -ls
Found 9 items
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_18
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_19
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_20
drwxrwxrwx   - cloudera cloudera          0 2017-08-02 13:10 2015_11_21
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 23:58 count2
drwxr-xr-x   - cloudera cloudera          0 2017-08-01 03:57 empcounts
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:45 shakespeare
drwxr-xr-x   - cloudera cloudera          0 2017-07-31 21:43 testlog
drwxr-xr-x   - cloudera cloudera          0 2019-06-14 15:08 weblog
[cloudera@quickstart data_ingest]$ hadoop fs -ls testlog
Found 1 items
-rw-r--r--   1 cloudera cloudera     485246 2017-07-31 21:43 testlog/test_access_log
[cloudera@quickstart data_ingest]$ hadoop fs -rm -r testlog
Deleted testlog
[cloudera@quickstart data_ingest]$ hadoop fs -ls testlog
ls: `testlog': No such file or directory
[cloudera@quickstart data_ingest]$ hadoop fs -mkdir testlog
[cloudera@quickstart data_ingest]$ hadoop fs -ls testlog
[cloudera@quickstart data_ingest]$ gunzip -c ~/training_materials/developer/data/access_log.gz | head -n 5000 | hadoop fs -put - testlog/test_access_log
[cloudera@quickstart data_ingest]$ hadoop fs -ls testlog
Found 1 items
-rw-r--r--   1 cloudera cloudera     485246 2019-06-14 15:16 testlog/test_access_log
