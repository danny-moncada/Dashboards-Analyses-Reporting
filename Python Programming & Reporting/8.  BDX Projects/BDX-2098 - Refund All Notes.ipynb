# %%
# %reload_ext ishbook
import pandas as pd
import plus
import xlsxwriter
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %%ish
#
# all_notes = from repaccountnotes 2016-07-01 2016-10-01 WHERE user_group_idstok IN (347,349,496,348,612) account_type = advertiser note_type = NOTE GROUP BY category_name,username,advid,note
#
# output = None

# %%
all_notes.tail()
# Out:
#                 category_name  username    advid  \
# 192936  Credit/Refund Request    yuliya  3583569
# 192937            no category     adlar  8147627
# 192938   Client Communication  whitneys  8887017
# 192939            no category      vlea    84580
# 192940            no category   dbagosy  1865046
#
#                                                      note
# 192936  ype of request: Refund/CreditAmt of Request: R...  1
# 192937  yvette woodard <yvettewoodard1@gmail.com>Aug 7...  1
# 192938  zroom dance and fitness emailed from a gmail. ...  1
# 192939  ​IB Phone & IB Email  1) Interaction Reason ::...  1
# 192940  — Bob ShaffnerSenior Leader, Talent Attraction...  1

# %%
# If there isn't a note category, then label as 'no note'

all_notes.note.fillna('no note',inplace=True)

# %% [markdown]
# **INTERACTION REASONS**: Job Visibility, Refund/Billing, Candidate Quality, Technical Troubleshoot, SQ Review, SQ Escalation, Product Issue, Budget Recommendations, Optimization/Problem Jobs, Upsell, NPS, Job Visibility, Reactivation
#
# **CLIENT TYPE**: Spending, Free, Inactive, Upsell **This is discontinued as it's no longer in the templates**
#
# **CUSTOMER SATISFACTION**: Happy, Neutral, Unhappy ** This is discontinued as it's no longer in the templates**

# %%
#Create a new df for notes that have an 'Interaction Reason' in the template

interaction_notes = all_notes.copy()

# %%
# Create function to isolate keywords for Interaction Reasons

def reason(string_in):
    if 'Job Visibility' in string_in:
        return 'Job Visibility'
    elif 'Visibility' in string_in:
        return 'Job Visibility'
    elif 'Refund/Billing' in string_in:
        return 'Refund/Billing'
    elif 'Billing' in string_in:
        return 'Refund/Billing'
    elif 'Refund' in string_in:
        return 'Refund/Billing'
    elif 'refund' in string_in:
        return 'Refund/Billing'
    elif 'Charges' in string_in:
        return 'Refund/Billing'
    elif 'Candidate Quality' in string_in:
        return 'Candidate Quality'
    elif 'Candidate quality' in string_in:
        return 'Candidate Quality'
    elif 'Technical Troubleshoot' in string_in:
        return 'Technical Troubleshoot'
    elif 'Technical' in string_in:
        return 'Technical Troubleshoot'
    elif 'Technical Issues' in string_in:
        return 'Technical Troubleshoot'
    elif 'Troubleshoot' in string_in:
        return 'Technical Troubleshoot'
    elif 'Server Error' in string_in:
        return 'Technical Troubleshoot'
    elif 'Change password' in string_in:
        return 'Technical Troubleshoot'
    elif 'Password Reset' in string_in:
        return 'Technical Troubleshoot'
    elif ':Tech troubleshoot' in string_in:
        return 'Technical Troubleshoot'
    elif 'SQ Review' in string_in:
        return 'SQ Review'
    elif 'Review' in string_in:
        return 'SQ Review'
    elif 'SQ Escalation' in string_in:
        return 'SQ Escalation'
    elif 'Product Issue' in string_in:
        return 'Product Issue'
    elif ':Product Issue' in string_in:
        return 'Product Issue'
    elif 'Budget Recommendations' in string_in:
        return 'Budget Recommendations'
    elif '/Budget' in string_in:
        return 'Budget Recommendations'
    elif 'budget' in string_in:
        return 'Budget Recommendations'
    elif 'Pricing' in string_in:
        return 'Pricing'
    elif 'Optimization/Problem Jobs' in string_in:
        return 'Optimization/Problem Jobs'
    elif 'Optimization/Problem' in string_in:
        return 'Optimization/Problem Jobs'
    elif 'Upsell' in string_in:
        return 'Upsell'
    elif 'NPS' in string_in:
        return 'NPS'
    elif 'Job Visibility' in string_in:
        return 'Job Visibility'
    elif 'Job Vis' in string_in:
        return 'Job Visibility'
    elif 'job visibility' in string_in:
        return 'Job Visibility'
    elif 'Job visibility' in string_in:
        return 'Job Visibility'
    elif 'Visibility' in string_in:
        return 'Job Visibility'
    elif 'Reactivation' in string_in:
        return 'Reactivation'
    elif 'Resume' in string_in:
        return 'Resume'
    elif 'Indeed resume' in string_in:
        return 'Resume'
    elif 'resume alerts' in string_in:
        return 'Resume'
    elif ':Indeed resume' in string_in:
        return 'Resume'
    elif 'Pausing' in string_in:
        return 'Pausing/Removing Job'
    elif 'Closing' in string_in:
        return 'Pausing/Removing Job'
    elif 'close jobs' in string_in:
        return 'Pausing/Removing Job'
    elif 'Close jobs' in string_in:
        return 'Pausing/Removing Job'
    elif 'Close a Job' in string_in:
        return 'Pausing/Removing Job'
    elif 'Close Job' in string_in:
        return 'Pausing/Removing Job'
    elif 'Apply URL/Indexing' in string_in:
        return 'Apply URL/Indexing'
    elif 'Apply URL' in string_in:
        return 'Apply URL/Indexing'
    elif 'disabled account' in string_in:
        return 'Disabled account'
    elif 'Company Page' in string_in:
        return 'Company Page'
    elif 'Company Pages' in string_in:
        return 'Company Page'
    elif 'Company Branding' in string_in:
        return 'Company Page'
    elif 'closing account' in string_in:
        return 'Closing Account'
    elif 'disabling account' in string_in:
        return 'Closing Account'
    elif 'Account closure' in string_in:
        return' Closing Account'
    elif 'Disable account' in string_in:
        return 'Closing Account'
    elif 'Post Job' in string_in:
        return 'Post a job help'
    elif 'Job Posting' in string_in:
        return 'Post a job help'
    elif 'Posting Job' in string_in:
        return 'Post a job help'
    elif 'Setting up job' in string_in:
        return 'Post a job help'
    elif 'Posting a Job' in string_in:
        return 'Post a job help'
    elif 'Confidential' in string_in:
        return 'Confidential posting'
    elif 'Account Navigation' in string_in:
        return 'Account Navigation'
    elif 'Pending Report' in string_in:
        return 'Pending Report'
    elif 'Escalation' in string_in:
        return 'Escalation'
    else:
        return 'Other'

# %%
# Map the functions to create a new columns

interaction_notes['reason'] = interaction_notes.note.map(reason).copy()

#interaction_notes['client_type'] = interaction_notes.note.map(clienttype).copy()
#interaction_notes['customer_satisfaction'] = interaction_notes.note.map(satisfaction).copy()

# %%
# Map Interaction Reasons to Teams
# Read in team doc from google

#teams = plus.read_google_sheet('114yDQZ7Fi6AhXBg2IhO3NZxEmAcvL12AuyXSIsZN38U',intype='key',sheet='Sheet1',headers=True,index=False)
# Out:
# LDAP name:
# dmoncada
# Password:
# ········

# %%
# Merge team data with interaction data

#interaction_notes_teams = interaction_notes.merge(teams,how='left',on='username')

# %%
refund_billing = interaction_notes[interaction_notes.reason == 'Refund/Billing']
#interaction_notes_teams[refund_billing]

# %%
refund_billing
# Out:
#                 category_name   username    advid  \
# 1         IB Phone & IB Email       rcid  7532035
# 162               no category     maddie  8815983
# 304               no category     esmith  8035886
# 325               no category    deseray  8412949
# 328               no category    deseray  5866591
# 350               no category     esmith  8261068
# 451               no category    deseray  7616211
# 615               no category    deseray  8213738
# 617               no category    deseray  8224643
# 619               no category    deseray  4818876
# 796               no category    deseray  7617317
# 876               no category    deseray  7706289
# 911               no category    ngarard  8765618
# 1459      IB Phone & IB Email  lvalencia  7406414
# 1468              no category     cheryl  8411796
# 1475              no category     cyrena  6675821
# 1477              no category   briannac  8285475
# 1485              no category     alanat  8016917
# ...

# %%
job_visibility = interaction_notes_teams[interaction_notes_teams.reason == 'Job Visibility']
refund_billing = interaction_notes_teams[interaction_notes_teams.reason == 'Refund/Billing']
candidate_quality = interaction_notes_teams[interaction_notes_teams.reason == 'Candidate Quality']
technical_troubleshoot = interaction_notes_teams[interaction_notes_teams.reason == 'Technical Troubleshoot']
SQ_review = interaction_notes_teams[interaction_notes_teams.reason == 'SQ Review']
SQ_escalation = interaction_notes_teams[interaction_notes_teams.reason == 'SQ Escalation']
product_issue = interaction_notes_teams[interaction_notes_teams.reason == 'Product Issue']
budget = interaction_notes_teams[interaction_notes_teams.reason == 'Budget Recommendations']
pricing = interaction_notes_teams[interaction_notes_teams.reason == 'Pricing']
optimization = interaction_notes_teams[interaction_notes_teams.reason == 'Optimization/Problem Jobs']
upsell = interaction_notes_teams[interaction_notes_teams.reason == 'Upsell']
nps = interaction_notes_teams[interaction_notes_teams.reason == 'NPS']
reactivation = interaction_notes_teams[interaction_notes_teams.reason == 'Reactivation']
resume = interaction_notes_teams[interaction_notes_teams.reason == 'Resume']
pausing = interaction_notes_teams[interaction_notes_teams.reason == 'Pausing/Removing Job']
applyURL = interaction_notes_teams[interaction_notes_teams.reason == 'Apply URL/Indexing']
disabled = interaction_notes_teams[interaction_notes_teams.reason == 'Disabled account']
companypage = interaction_notes_teams[interaction_notes_teams.reason == 'Company Page']
closing = interaction_notes_teams[interaction_notes_teams.reason == 'Closing Account']
postajobhelp = interaction_notes_teams[interaction_notes_teams.reason == 'Post a job help']
confidential = interaction_notes_teams[interaction_notes_teams.reason == 'Confidential posting']
accountnav = interaction_notes_teams[interaction_notes_teams.reason == 'Account Navigation']
pendingreport = interaction_notes_teams[interaction_notes_teams.reason == 'Pending Report']
escalation = interaction_notes_teams[interaction_notes_teams.reason == 'Escalation']
other = interaction_notes_teams[interaction_notes_teams.reason == 'Other']
