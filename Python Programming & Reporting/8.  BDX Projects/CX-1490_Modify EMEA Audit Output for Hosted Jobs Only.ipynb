# %%
# %reload_ext ishbook
import pandas as pd
import plus
import datetime as dt

# %% [markdown]
# ## Pull in the advertiser report provided from Luis
#
# - This is taken from the adCentral report that is run bi-weekly on Tuesdays/Thursdays
# - Exclude any rows from the df where the **Advertiser ID** are null (causes issues when creating a string of the IDs to feed in the IQL pulls)
# - Check the len of the df before and after to make sure those rows were dropped

# %%
adCentral_csv = pd.read_csv("SCS EMEA B 915.csv")
print len(adCentral_csv)
# Out:
# 280

# %%
adCentral_csv = adCentral_csv[pd.notnull(adCentral_csv['Advertiser ID'])]
print len(adCentral_csv)
# Out:
# 268

# %% [markdown]
# ## Set Advertiser ID column as int and create a string listed for IQL Query
#
# - Advertiser ID comes in as object so needs to be converted

# %%
adCentral_csv['Advertiser ID'] = adCentral_csv['Advertiser ID'].astype(int)

# %%
advids = ",".join(str(x) for x in adCentral_csv["Advertiser ID"])

# %% [markdown]
# ## Checking for Indexed / Hosted Clicks & Dradis Jobs
# - Use the **adclick** index to pulll in indexed and hosted clicks
# - Use the **hostedjobsnapshot** index to look at any advertisers that had Dradis jobs

# %%
# %%ish
# indexed = from adclick 2012-01-01 today WHERE advid in ({advids}) and type = "chg" feedid !=50461 group by advid/*Advertiser ID*/ select count() /*sponsored indexed Clicks*/
# output = None
# dradis = from adclick 2012-01-01 today WHERE advid in ({advids}) and type = "chg" feedid =50461 group by advid/*Advertiser ID*/ select count() /*sponsored dradis Clicks*/
# output = None
# dradisjobs = from hostedjobsnapshot 2014-07-01 today WHERE advertiserid in ({advids}) and status = ('active') group by advertiserid/*Advertiser ID*/ select count() /*hosted jobs*/
# output = None

# %% [markdown]
# ## Merge the adCentral df with the output from the IQL queries above
# - This could probably be done in one line but for the sake of cleanliness I merged it on three separate lines

# %%
first_merge = adCentral_csv.merge(indexed, how = "left", left_on = "Advertiser ID", right_on = "Advertiser ID")
second_merge = first_merge.merge(dradis, how = "left", left_on = "Advertiser ID", right_on = "Advertiser ID")
final_merge = second_merge.merge(dradisjobs, how = "left", left_on = "Advertiser ID", right_on = "Advertiser ID")
final_merge = final_merge[['Advertiser ID','Account ID','sponsored indexed Clicks','sponsored dradis Clicks','hosted jobs']]

# %% [markdown]
# ## Pull out any advertisers with sponsored jobs and hosted jobs only

# %%
final_merge = final_merge[pd.isnull(final_merge['sponsored indexed Clicks'])]
final_merge = final_merge[pd.notnull(final_merge['hosted jobs'])]

# %%
final_merge.tail()
# Out:
#      Advertiser ID   Account ID  sponsored indexed Clicks  \
# 263        7991164  247009341.0                       NaN
# 264        8026276  247378776.0                       NaN
# 265        8066349  247874157.0                       NaN
# 266        8070863  247920054.0                       NaN
# 267        8072787  247938256.0                       NaN
#
#      sponsored dradis Clicks  hosted jobs
# 263                      NaN        276.0
# 264                      NaN        369.0
# 265                      NaN        216.0
# 266                      NaN         83.0
# 267                      NaN        162.0

# %%
len(final_merge)
# Out:
# 183

# %% [markdown]
# ## Set the Assignment ID to 3271 for all the remaning rows and add the date
# - Create a new column labeled **Assignment ID** and set it equal to 3271
# - Create a separate column **Date** and set it to today's date using the datetime function

# %%
final_merge['New User Id'] = 3271
final_merge["Relationship"] = "SERVICE_REP"

# %%
final_merge['Date Assignment Starts'] = dt.datetime.today().strftime("%m/%d/%y")

# %%
final_merge
# Out:
#      Advertiser ID   Account ID  sponsored indexed Clicks  \
# 1          2870701  180889518.0                       NaN
# 2          5286636  215212711.0                       NaN
# 3           140420   67845114.0                       NaN
# 4          2542763  175445944.0                       NaN
# 6          2102204  166382083.0                       NaN
# 10          318056   98057170.0                       NaN
# 13         4681940  208045916.0                       NaN
# 21           88997   48245402.0                       NaN
# 26          190074   82706742.0                       NaN
# 27          195843   83844598.0                       NaN
# 29          208481   86784030.0                       NaN
# 30          209814   87146306.0                       NaN
# 31          210420   86311226.0                       NaN
# 33          222203   89938214.0                       NaN
# 35          241263   93774350.0                       NaN
# 36          243816   94336426.0                       NaN
# 37          243855   94344938.0                       NaN
# 38          310016   96904930.0                       NaN
# 40          368659  105838554.0                       NaN
# 41          371796  106464062.0                       NaN
# 42          388052  109737550.0                       NaN
# 43          389911  110047126.0                       NaN
# 44          397437  111396567.0                       NaN
# 45          399583  111485584.0                       NaN
# 46          401737  111576668.0                       NaN
# 50          418812  112346079.0                       NaN
# 51          419721  112389009.0                       NaN
# 52         1861235  159910343.0                       NaN
# 53         1861810  159926069.0                       NaN
# 54         1866175  160031623.0                       NaN
# ..             ...          ...                       ...
# 226        5895361  222999981.0                       NaN
# 228        5968599  223905111.0                       NaN
# 229        5984276  224088067.0                       NaN
# 230        7564059  242057930.0                       NaN
# 231        7564759  242064649.0                       NaN
# 233        7603915  242559624.0                       NaN
# 234        7605020  227992659.0                       NaN
# 235        7605237  242574781.0                       NaN
# 239        7655877  243123262.0                       NaN
# 240        7674160  243315804.0                       NaN
# 242        7692910  243555348.0                       NaN
# 243        7723414  243899832.0                       NaN
# 244        7734854  244026435.0                       NaN
# 245        7736449  244043120.0                       NaN
# 246        7738574  244030528.0                       NaN
# 249        7831272  156577675.0                       NaN
# 250        7832840  245131799.0                       NaN
# 252        7846785  245286922.0                       NaN
# 255        7872149  245582679.0                       NaN
# 256        7882116  245743321.0                       NaN
# 258        7915384  246131170.0                       NaN
# 259        7929024  246276183.0                       NaN
# 260        7932752  246311700.0                       NaN
# 261        7945505  246449714.0                       NaN
# 262        7969614  246779224.0                       NaN
# 263        7991164  247009341.0                       NaN
# 264        8026276  247378776.0                       NaN
# 265        8066349  247874157.0                       NaN
# 266        8070863  247920054.0                       NaN
# 267        8072787  247938256.0                       NaN
#
#      sponsored dradis Clicks  hosted jobs  New User Id Relationship  \
# 1                    27593.0        705.0         3271  SERVICE_REP
# 2                    49583.0       1851.0         3271  SERVICE_REP
# 3                    31031.0       1076.0         3271  SERVICE_REP
# 4                     2199.0        481.0         3271  SERVICE_REP
# 6                    15086.0       1992.0         3271  SERVICE_REP
# 10                    7723.0        948.0         3271  SERVICE_REP
# 13                     908.0       2716.0         3271  SERVICE_REP
# 21                       NaN       1904.0         3271  SERVICE_REP
# 26                       NaN       1557.0         3271  SERVICE_REP
# 27                       NaN       1373.0         3271  SERVICE_REP
# 29                       NaN       5179.0         3271  SERVICE_REP
# 30                       NaN       4956.0         3271  SERVICE_REP
# 31                      39.0       3304.0         3271  SERVICE_REP
# 33                       NaN        413.0         3271  SERVICE_REP
# 35                       NaN       1652.0         3271  SERVICE_REP
# 36                       NaN       1652.0         3271  SERVICE_REP
# 37                       NaN       1015.0         3271  SERVICE_REP
# 38                       NaN        413.0         3271  SERVICE_REP
# 40                       NaN       1906.0         3271  SERVICE_REP
# 41                       NaN        733.0         3271  SERVICE_REP
# 42                     155.0       3717.0         3271  SERVICE_REP
# 43                       NaN       5369.0         3271  SERVICE_REP
# 44                       NaN       2891.0         3271  SERVICE_REP
# 45                       NaN      11211.0         3271  SERVICE_REP
# 46                       NaN       3304.0         3271  SERVICE_REP
# 50                       NaN       1717.0         3271  SERVICE_REP
# 51                       NaN        413.0         3271  SERVICE_REP
# 52                       NaN        335.0         3271  SERVICE_REP
# 53                       NaN        826.0         3271  SERVICE_REP
# 54                       NaN       1652.0         3271  SERVICE_REP
# ..                       ...          ...          ...          ...
# 226                      NaN         71.0         3271  SERVICE_REP
# 228                      NaN       1056.0         3271  SERVICE_REP
# 229                      NaN        608.0         3271  SERVICE_REP
# 230                      NaN        846.0         3271  SERVICE_REP
# 231                      NaN        196.0         3271  SERVICE_REP
# 233                      NaN        893.0         3271  SERVICE_REP
# 234                      NaN        216.0         3271  SERVICE_REP
# 235                      NaN        282.0         3271  SERVICE_REP
# 239                      NaN        380.0         3271  SERVICE_REP
# 240                      NaN        310.0         3271  SERVICE_REP
# 242                      NaN        405.0         3271  SERVICE_REP
# 243                   2901.0        159.0         3271  SERVICE_REP
# 244                      NaN         85.0         3271  SERVICE_REP
# 245                      NaN         56.0         3271  SERVICE_REP
# 246                      NaN        110.0         3271  SERVICE_REP
# 249                      NaN        259.0         3271  SERVICE_REP
# 250                      NaN        311.0         3271  SERVICE_REP
# 252                      NaN        385.0         3271  SERVICE_REP
# 255                      NaN        140.0         3271  SERVICE_REP
# 256                      NaN        183.0         3271  SERVICE_REP
# 258                      NaN         71.0         3271  SERVICE_REP
# 259                      NaN        214.0         3271  SERVICE_REP
# 260                      NaN        607.0         3271  SERVICE_REP
# 261                      NaN        360.0         3271  SERVICE_REP
# 262                      NaN        520.0         3271  SERVICE_REP
# 263                      NaN        276.0         3271  SERVICE_REP
# 264                      NaN        369.0         3271  SERVICE_REP
# 265                      NaN        216.0         3271  SERVICE_REP
# 266                      NaN         83.0         3271  SERVICE_REP
# 267                      NaN        162.0         3271  SERVICE_REP
#
#     Date Assignment Starts
# 1                 09/15/16
# 2                 09/15/16
# 3                 09/15/16
# 4                 09/15/16
# 6                 09/15/16
# 10                09/15/16
# 13                09/15/16
# 21                09/15/16
# 26                09/15/16
# 27                09/15/16
# 29                09/15/16
# 30                09/15/16
# 31                09/15/16
# 33                09/15/16
# 35                09/15/16
# 36                09/15/16
# 37                09/15/16
# 38                09/15/16
# 40                09/15/16
# 41                09/15/16
# 42                09/15/16
# 43                09/15/16
# 44                09/15/16
# 45                09/15/16
# 46                09/15/16
# 50                09/15/16
# 51                09/15/16
# 52                09/15/16
# 53                09/15/16
# 54                09/15/16
# ..                     ...
# 226               09/15/16
# 228               09/15/16
# 229               09/15/16
# 230               09/15/16
# 231               09/15/16
# 233               09/15/16
# 234               09/15/16
# 235               09/15/16
# 239               09/15/16
# 240               09/15/16
# 242               09/15/16
# 243               09/15/16
# 244               09/15/16
# 245               09/15/16
# 246               09/15/16
# 249               09/15/16
# 250               09/15/16
# 252               09/15/16
# 255               09/15/16
# 256               09/15/16
# 258               09/15/16
# 259               09/15/16
# 260               09/15/16
# 261               09/15/16
# 262               09/15/16
# 263               09/15/16
# 264               09/15/16
# 265               09/15/16
# 266               09/15/16
# 267               09/15/16
#
# [183 rows x 8 columns]

# %% [markdown]
# ## Set the Account ID to an int since it is float, this will allow the file to be uploaded to AdCentral

# %%
final_merge['Account Id'] = final_merge['Account ID'].apply(lambda x: int(x))
final_merge = final_merge[['Account Id','Relationship', 'New User Id', 'Date Assignment Starts']]
print final_merge.tail(10)
print len(final_merge)
# Out:
#      Account Id Relationship  New User Id Date Assignment Starts
# 258   246131170  SERVICE_REP         3271               09/15/16
# 259   246276183  SERVICE_REP         3271               09/15/16
# 260   246311700  SERVICE_REP         3271               09/15/16
# 261   246449714  SERVICE_REP         3271               09/15/16
# 262   246779224  SERVICE_REP         3271               09/15/16
# 263   247009341  SERVICE_REP         3271               09/15/16
# 264   247378776  SERVICE_REP         3271               09/15/16
# 265   247874157  SERVICE_REP         3271               09/15/16
# 266   247920054  SERVICE_REP         3271               09/15/16
# 267   247938256  SERVICE_REP         3271               09/15/16
# 183

# %% [markdown]
# ## Export the finalized output to CSV for Luis to upload into adCentral
# - Set the index to false since we don't need that in the final output

# %%
final_merge.to_csv('SCS EMEA B 915 FINAL.csv', index=False)
