# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
from ggplot import *
# %matplotlib inline
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# C:\Users\monca016\AppData\Local\Continuum\anaconda3\envs\env_full\lib\site-packages\ggplot\utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# C:\Users\monca016\AppData\Local\Continuum\anaconda3\envs\env_full\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
starbucks = pd.read_excel("starbucks.xlsx")

# %%
y = pd.DataFrame(starbucks['carb'])

# %%
x = pd.DataFrame(starbucks['calories'])

# %%
lm = linear_model.LinearRegression()
model = lm.fit(x,y)

# %% [markdown]
# # R2

# %%
lm.score(x, y)
# Out:
# 0.4556236754779176

# %%
print(lm.coef_)
print()
print(lm.intercept_)
# Out:
# [[10.60308871]]
#
# [8.94356048]

# %%
predictions = lm.predict(x)
print(predictions[2:4])
# Out:
# [[53.47653304]
#  [60.89869513]]

# %%
np.sqrt(mean_squared_error(y, predictions))
# Out:
# 12.132545501671071

# %%
with plt.style.context('ggplot'):
    plt.scatter(x, y,  color='black')
    plt.plot(x, predictions, 'r-', linewidth = .5)
    plt.show()

# %%
ggplot(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ae439a439e37> in <module>()
# ----> 1 ggplot(x, y)
#
# ~\AppData\Local\Continuum\anaconda3\envs\env_full\lib\site-packages\ggplot\ggplot.py in __init__(self, aesthetics, data)
#      53         self._aes = aesthetics
#      54         self.data = data.copy()
# ---> 55         self._handle_index()
#      56         self.data = self._aes._evaluate_expressions(self.data)
#      57         self.data = self._aes.handle_identity_values(self.data)
#
# ~\AppData\Local\Continuum\anaconda3\envs\env_full\lib\site-packages\ggplot\ggplot.py in _handle_index(self)
#     132
#     133     def _handle_index(self):
# --> 134         if '__index__' in self._aes.values():
#     135             self.data['__index__'] = self.data.index
#     136
#
# TypeError: 'numpy.ndarray' object is not callable
